# %% [markdown]
# <a href="https://colab.research.google.com/github/Noo2r/Port_Flow_AI/blob/feature%2Fweek1-ai-setup/ai/experiments/eta_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Clean notebook test")
# Out:
# Clean notebook test
